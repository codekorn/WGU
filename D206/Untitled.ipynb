# %%
import pandas as pd

# %%
df = pd.read_csv('churn_clean.csv')

# %%
df.head()
# Out:
#    CaseOrder Customer_id                           Interaction  \
# 0          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 1          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 2          3     K191035  344d114c-3736-4be5-98f7-c72c281e2d35
# 3          4      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311
# 4          5     K662701  68a861fd-0d20-4e51-a587-8a90407ee574
#
#                                 UID         City State                 County  \
# 0  e885b299883d4f9fb18e39c75155d990  Point Baker    AK  Prince of Wales-Hyder
# 1  f2de8bef964785f41a2959829830fb8a  West Branch    MI                 Ogemaw
# 2  f1784cfa9f6d92ae816197eb175d3c71      Yamhill    OR                Yamhill
# 3  dc8a365077241bb5cd5ccd305136b05e      Del Mar    CA              San Diego
# 4  aabb64a116e83fdc4befc1fbab1663f9    Needville    TX              Fort Bend
#
#      Zip       Lat        Lng  ...  MonthlyCharge Bandwidth_GB_Year Item1  \
# ...

# %%
df_first = df.head(1).transpose()

# %%
df_first['type'] = df.dtypes

# %%
df_first.rename(columns={0: 'Variable Name', 'a': 'DataType'}, inplace=True)

# %%
df_first.head()
# Out:
#                                     Variable Name DataType
# CaseOrder                                       1    int64
# Customer_id                               K409198   object
# Interaction  aa90260b-4141-4a24-8e36-b04ce1f4f77b   object
# UID              e885b299883d4f9fb18e39c75155d990   object
# City                                  Point Baker   object

# %%
df_first['DataType'] = 'Quantitative' if df_first['DataType'] == 'object' else 'Qualitative'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 df_first['DataType'] = 'Quantitative' if df_first['DataType'] == 'object' else 'Qualitative'
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
