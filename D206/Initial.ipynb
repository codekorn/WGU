# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('churn_clean.csv')

# %%
df.head()
# Out:
#    CaseOrder Customer_id                           Interaction  \
# 0          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 1          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 2          3     K191035  344d114c-3736-4be5-98f7-c72c281e2d35
# 3          4      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311
# 4          5     K662701  68a861fd-0d20-4e51-a587-8a90407ee574
#
#                                 UID         City State                 County  \
# 0  e885b299883d4f9fb18e39c75155d990  Point Baker    AK  Prince of Wales-Hyder
# 1  f2de8bef964785f41a2959829830fb8a  West Branch    MI                 Ogemaw
# 2  f1784cfa9f6d92ae816197eb175d3c71      Yamhill    OR                Yamhill
# 3  dc8a365077241bb5cd5ccd305136b05e      Del Mar    CA              San Diego
# 4  aabb64a116e83fdc4befc1fbab1663f9    Needville    TX              Fort Bend
#
#      Zip       Lat        Lng  ...  MonthlyCharge Bandwidth_GB_Year Item1  \
# ...

# %%
df_first = df.head(1).transpose()

# %%
df_first['a'] = df.dtypes

# %%
df_first.rename(columns={0: 'Example', 'a': 'DataType'}, inplace=True)

# %%
df_first.head()
# Out:
#                                           Example DataType
# CaseOrder                                       1    int64
# Customer_id                               K409198   object
# Interaction  aa90260b-4141-4a24-8e36-b04ce1f4f77b   object
# UID              e885b299883d4f9fb18e39c75155d990   object
# City                                  Point Baker   object

# %%
df_first['DataCat'] = np.where(df_first['DataType'] == 'object','Qualitative', 'Quantitative' )

# %%
df_first.loc['Zip', 'DataCat'] = 'Qualitative'

# %%
df_first.loc['Item1':, 'DataCat'] = 'Qualitative'

# %%
df_first.index.names = ['Variable Name']

# %%
df_first.to_csv('variables.csv')

# %%
df_first['Explanation'] = ''

# %%
df_first
# Out:
#                                                    Example DataType  \
# Variable Name
# CaseOrder                                                1    int64
# Customer_id                                        K409198   object
# Interaction           aa90260b-4141-4a24-8e36-b04ce1f4f77b   object
# UID                       e885b299883d4f9fb18e39c75155d990   object
# City                                           Point Baker   object
# State                                                   AK   object
# County                               Prince of Wales-Hyder   object
# Zip                                                  99927    int64
# Lat                                                 56.251  float64
# Lng                                             -133.37571  float64
# Population                                              38    int64
# Area                                                 Urban   object
# TimeZone                                     America/Sitka   object
# ...

# %%
df.columns
# Out:
# Index(['CaseOrder', 'Customer_id', 'Interaction', 'UID', 'City', 'State',
#        'County', 'Zip', 'Lat', 'Lng', 'Population', 'Area', 'TimeZone', 'Job',
#        'Children', 'Age', 'Income', 'Marital', 'Gender', 'Churn',
#        'Outage_sec_perweek', 'Email', 'Contacts', 'Yearly_equip_failure',
#        'Techie', 'Contract', 'Port_modem', 'Tablet', 'InternetService',
#        'Phone', 'Multiple', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'PaymentMethod', 'Tenure', 'MonthlyCharge',
#        'Bandwidth_GB_Year', 'Item1', 'Item2', 'Item3', 'Item4', 'Item5',
#        'Item6', 'Item7', 'Item8'],
#       dtype='object', name='Variable Name')

# %%
df_first.iloc[0,3] = 'This column is a place holder to ensure the original order will be kept.'

# %%
df_first.iloc[1,3] = 'This column contains a unique ID for the customer.'

# %%
df_first.iloc[2,3] =  """A unique ID which relates to technical interactions,
                        including sign-up, support and transactions."""

# %%
df_first.iloc[3,3] = """A unique ID which relates to technical interactions,
                        including sign-up, support and transactions."""

# %%
df_first.iloc[4,3] = 'The city included on the billing address of the customer.'

# %%
df_first.iloc[5,3] = 'The state included on the billing address of the customer.'

# %%
df_first.iloc[6,3] = 'The county included on the billing address of the customer.'

# %%
df_first.iloc[7,3] = 'The zipcode included on the billing address of the customer.'

# %%
df_first.iloc[8,3] = 'The latitude based on the billing address of the customer.'

# %%
df_first.iloc[9,3] = 'The longitude based on the billing address of the customer.'

# %%
df_first.iloc[10,3] = 'The population within a one mile radius of the customer, retrieved from census data.'

# %%
df_first.iloc[11,3] = 'Categorized area type retrieved from census data. Can be one of the following: rural, urban and suburban.'

# %%
df_first.iloc[12,3] = 'Timezone of the customer based on sign-up info (not billing).'

# %%
df_first.iloc[13,3] = 'Profession of the customer, based on sign-up info.'

# %%
df_first.iloc[14,3] = 'Amount of children the customer has, based on sign-up info.'

# %%
df_first.iloc[15,3] = 'Age of the customer, based on sign-up info.'

# %%
df_first.iloc[16,3] = 'Annual income of the customer, based on sign-up info.'

# %%
df_first.iloc[17,3] = 'Marital Status of the customer, based on sign-up info.'

# %%
df_first.iloc[18,3] = 'Gender of the customer, based on sign-up info.'

# %%
df_first.iloc[19,3] = 'Whether the customer has churned or not. This is the target variable for future model predictions. Answer can be yes or no.'

# %%
df_first.iloc[20,3] = 'The average time in seconds the customer\'s neighberhood experienced system outages.'

# %%
df_first.iloc[21,3] = 'The amount of emails that were sent to customer in the previous year.'

# %%
df_first.iloc[22,3] = 'The amount of times the customer reached out to customer support. For new customers, this column reflects the amount of times customers with simillar profiles have reached out to customer support.'

# %%
df_first.iloc[23,3] = 'How many times did the customer\'s equipment fail durng the previous year, and it was either replaced or reset. For new customers, this column reflects the amount of times customers with simillar profiles have experienced equipment failures.'

# %%
df_first.iloc[24,3] = 'Does the customer consider themselves technically savy. This question was asked on the sign-up questionnaire. Answer can be yes or no.'

# %%
df_first.iloc[25,3] = 'How long is the customer\'s contract for. Can be either monthly, annualy or for two years.'

# %%
df_first.iloc[26,3] = 'Does the customer have a portable modem or not. Answer can be yes or no.'

# %%
df_first.iloc[27,3] = 'Does the customer own a tablet or not. Answer can be yes or no.'

# %%
df_first.iloc[28,3] = 'The internet service provider of the customer.'

# %%
df_first.iloc[29,3] = 'Does the customer own a phone or not. Answer can be yes or no.'

# %%
df_first.iloc[30,3] = 'Does the customer have multiple phone lines or not. Answer can be yes or no.'

# %%
df_first.iloc[31,3] = 'Does the customer have the online security add-on or not. Answer can be yes or no.'

# %%
df_first.iloc[32,3] = 'Does the customer have the online backup add-on or not. Answer can be yes or no.'

# %%
df_first.iloc[33,3] = 'Does the customer have the device protection add-on or not. Answer can be yes or no.'

# %%
df_first.iloc[34,3] = 'Does the customer have the technical support add-on or not. Answer can be yes or no.'

# %%
df_first.iloc[35,3] = 'Does the customer have streaming TV or not. Answer can be yes or no.'

# %%
df_first.iloc[36,3] = 'Does the customer have streaming movies or not. Answer can be yes or no.'

# %%
df_first.iloc[37,3] = 'Does the customer have paperless billing or not. Answer can be yes or no.'

# %%
df_first.iloc[38,3] = 'How does the customer pay for the service. Answer can be: check (mailed, electronic), or automatic (bank trasfer, credit card).'

# %%
df_first.iloc[39,3] = 'The amount of time in months the customer has retained service.'

# %%
df_first.iloc[40,3] = 'How much does the customer pay per month on average. For new customers, this column reflects the average spend value for customers with the same profile.'

# %%
df_first.iloc[41,3] = 'How many GB of data does the customer use per year on average. For new customers who haven\'t yet concluded a year of service, this column reflects the either the data usage approximated from thier use up to this point, or average data usage for regular customers within the same demographic profile.'

# %%
df_first['Variable'] = df_first.index

# %%
df_export = df_first[['Variable','DataCat','Explanation', 'Example']]

# %%
df_export['DataCat'] = '\n\u2022 Data Type: ' + df_first['DataCat']
df_export.Explanation  = '\n\u2022 ' + df_export.Explanation
df_export.Example  = '\n\u2022 Example: ' + df_export.Example.astype(str)
# Out:
# /var/folders/kp/qpd_hfrx4rsf69s67ws3jxkr0000gn/T/ipykernel_16062/4143171363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['DataCat'] = '\n\u2022 Data Type: ' + df_first['DataCat']
# /var/folders/kp/qpd_hfrx4rsf69s67ws3jxkr0000gn/T/ipykernel_16062/4143171363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export.Explanation  = '\n\u2022 ' + df_export.Explanation
# ...

# %%
df_export
# Out:
#                                   Variable                      DataCat  \
# Variable Name
# CaseOrder                        CaseOrder  \n• Data Type: Quantitative
# Customer_id                    Customer_id   \n• Data Type: Qualitative
# Interaction                    Interaction   \n• Data Type: Qualitative
# UID                                    UID   \n• Data Type: Qualitative
# City                                  City   \n• Data Type: Qualitative
# State                                State   \n• Data Type: Qualitative
# County                              County   \n• Data Type: Qualitative
# Zip                                    Zip   \n• Data Type: Qualitative
# Lat                                    Lat  \n• Data Type: Quantitative
# Lng                                    Lng  \n• Data Type: Quantitative
# Population                      Population  \n• Data Type: Quantitative
# Area                                  Area   \n• Data Type: Qualitative
# ...

# %%
np.savetxt('b.txt', df_export, newline='\n\n',  fmt = "%s")
